# %%
from pyspark.sql.functions import *
from pyspark.sql import SparkSession,DataFrame
from typing import Union,List
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import utils

# %% [markdown]
# ## INTRODUCCIÓN
#
# This project is to experiment with different kinds of graphics and data.

# %%
spark = SparkSession.builder.getOrCreate()
df =  read_csv_table(spark,"transactions")
df_left = read_csv_table(spark,"customers")
join_df = join_dataframe(df,df_left,"customer_code","left")
plot_bar_char(join_df,"customer_type","sales_amount")

# Crear un DataFrame de ejemplo

# %%
df =  read_csv_table(spark,"transactions")
df = df.withColumnRenamed("order_date", "date")
df_second = read_csv_table(spark,"dates")
join_df = join_dataframe(df,df_second,"date","left")
plot_line_char(join_df,"cy-date","sales_amount")

# %%
df =  read_csv_table(spark,"transactions")

df_left = read_csv_table(spark,"markets")
join_df = join_dataframe(df,df_left,"market_code","left")
plot_bar_char(join_df,"markets_name","sales_qty")

# %%
df =  read_csv_table(spark,"transactions")
plot_histogram(df,"sales_amount")

# %%
df =  read_csv_table(spark,"transactions")

plot_correlation_matrixt(df)
# Out:
#               sales_qty  sales_amount
# sales_qty      1.000000      0.343984
# sales_amount   0.343984      1.000000
